# %%
#q1
from matplotlib import pyplot as plt
import numpy as np


fig1 =  plt.figure()
ax = fig1.add_axes([0,0,1,1])
x = [0,100]
y = [0,200]
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('q1')
# Out:
# Text(0.5, 1.0, 'q1')

# %%
#q2
fig2 = plt.figure()

ax1 = fig2.add_axes([0,0,1,1])

ax2 = fig2.add_axes([0.2,0.5,0.2,0.2])

x= [0,2,4,6,8,10]
y= [0,4,16,36,64,100]

ax1.plot(x,y)

ax2.plot(y,x)

ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2.set_xlabel('y')
ax2.set_ylabel('x')

ax1.set_title('q2')
# Out:
# Text(0.5, 1.0, 'q2')

# %%
#q3
import csv
import pandas as pd
import matplotlib.pyplot as plt

company = pd.read_csv("/home/student/Desktop/company_sales_data.csv")
company_df = pd.DataFrame(company)
print(company_df)
month =  company_df['month_number']
profit = company_df['total_profit']

fig3 = plt.figure()

ax3 = fig3.add_axes([0,0,1,1])
ax3.set_xlabel('Month Number')
ax3.set_ylabel('Total Profit')
ax3.set_title('q3')

ax3.plot(month,profit)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-61e7492faf00> in <module>
#       1 #q3
#       2 import csv
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#q4

plt.plot(month, profit , linestyle= '--' , color='red', linewidth = 3 , marker = 'o', mfc='k' ,label ="Profit data of last year",)
plt.xlabel("Month Number")
plt.ylabel("Sold units nuber")
plt.title("Company Sales Data of Last Year")
plt.legend( loc = 4)
plt.ylim(100000)
plt.xlim()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6e24f28b7ab3> in <module>
#       1 #q4
#       2
# ----> 3 plt.plot(month, profit , linestyle= '--' , color='red', linewidth = 3 , marker = 'o', mfc='k' ,label ="Profit data of last year",)
#       4 plt.xlabel("Month Number")
#       5 plt.ylabel("Sold units nuber")
#
# NameError: name 'plt' is not defined

# %%
for col in company_df.iloc[:,1:7]:
    plt.plot(month, company_df[col] ,  linewidth = 3 , marker = 'o', mfc='k' ,label =col,)
plt.legend()
